# %%
import requests
import base64
import numpy as np
from PIL import Image, ImageDraw

import warnings
warnings.filterwarnings("ignore")

# %%
page = requests.get("http://127.0.0.1:8150/GetFace")
response=page.json()
narr=np.fromstring(base64.b64decode(response['Image']), np.uint8).reshape(response['Width'],response['Height'],3)
Image.fromarray(narr)
# Out:
# <PIL.Image.Image image mode=RGB size=181x181 at 0x1FEB900EF10>

# %%
print(response)
# Out:
# {'Image': '...', 'Length': 1, 'X': 213, 'Y': 119, 'Width': 182, 'Height': 182}
